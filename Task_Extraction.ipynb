# %%
# Import required modules
from src.task_extractor import identify_tasks
from src.categorizer import categorize_tasks
from src.utils import save_to_json

# Load sample data
with open("../data/sample.txt", "r") as file:
    text = file.read()

# Extract and categorize tasks
tasks = identify_tasks(text)
categorized_tasks = categorize_tasks(tasks)

# Save to JSON
save_to_json(categorized_tasks)
print("Task extraction and categorization completed! Results saved in output/results.json")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Import required modules
# ----> 2 from src.task_extractor import identify_tasks
#       3 from src.categorizer import categorize_tasks
#       4 from src.utils import save_to_json
#
# File ~\Documents\Vijayi WFH Technologies\task_extraction\src\task_extractor.py:2
#       1 import re
# ----> 2 from .preprocess import clean_text, pos_tagging, extract_entities
#       4 # Define common action verbs for task identification
#       5 action_verbs = ["buy", "clean", "schedule", "submit", "email", "call", "review"]
#
# File ~\Documents\Vijayi WFH Technologies\task_extraction\src\preprocess.py:2
#       1 import re
# ----> 2 import spacy
#       3 import nltk
#       4 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'spacy'

# %%
pip install spacy
# Out:
# ...
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [106 lines of output]
#   Ignoring numpy: markers 'python_version < "3.9"' don't match your environment
# ...
#     Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#     Using cached cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# ...
#     Using cached preshed-3.0.9.tar.gz (14 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
# ...

# %%
# !pip install spacy
# Out:
# ...
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [105 lines of output]
#   Ignoring numpy: markers 'python_version < "3.9"' don't match your environment
# ...
#     Using cached setuptools-78.1.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#     Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#     Using cached cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# ...
#     Using cached preshed-3.0.9.tar.gz (14 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
# ...

# %%
# !pip install spacy
# Out:
# ...
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [105 lines of output]
#   Ignoring numpy: markers 'python_version < "3.9"' don't match your environment
# ...
#     Using cached setuptools-78.1.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#     Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#     Using cached cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# ...
#     Using cached preshed-3.0.9.tar.gz (14 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
# ...
